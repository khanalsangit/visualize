# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('student_data.csv')
df.head()
# Out:
#    day  no_of_students
# 0    1              25
# 1    2              30
# 2    3              18
# 3    4              35
# 4    5              22

# %%
df.shape
# Out:
# (30, 2)

# %%
def visualizer(x,y):
    visualize=plt.plot(x,y)
    return visualize

# %%
visualizer(df['day'],df['no_of_students'])

# %%
import pickle

# %%
pickle.dump(visualize,open('model_place.pkl','wb'))

# %%
with open('/jamun/data visualization/model_place.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
d=(1,2,3,4,5)
s=(5,8,9,6,4)

# %%
visualizer(d,s)
