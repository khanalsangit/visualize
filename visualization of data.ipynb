# %%
import pickle
import matplotlib.pyplot as plt
# %run my_visualizer.ipynb

# %%
with open('visualizer_function.pkl', 'rb') as file:
    loaded_visualizer = pickle.load(file)

# %%
x_data = [1, 2, 3, 4, 5, 6, 7, 8]
y_data= [10, 20, 15, 30, 35,43,54,64]

# %%
x_data.append(10)
y_data.append(84)

# %%
loaded_visualizer(x_data, y_data)

# %%
import pandas as pd

# %%
data=pd.read_csv('student_data.csv')
df.head()
# Out:
#    day  no_of_students
# 0    1              25
# 1    2              30
# 2    3              18
# 3    4              35
# 4    5              22

# %%
x=df['day'].tolist()
y=df['no_of_students'].tolist()

# %%
x.append(40)
y.append(40)

# %%
loaded_visualizer(x,y)
